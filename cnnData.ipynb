# %% [markdown]
# <a href="https://colab.research.google.com/github/sandipanbasu/aiml-capstone/blob/master/cnnData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import tensorflow as tf
import tensorflow_datasets as tfds

import pandas as pd
import numpy as np

from tqdm import tqdm

# %%
tf.__version__
# Out:
# '2.2.0'

# %%
cd_path = "/content/drive/My Drive/AIML-MRC-Capstone/code/cnn-daily-mail"
cnn_file = "cnn_stories_tokenized.zip"
filePath = "/content/drive/My Drive/cnn-dailymail/cnn_stories_tokenized"

# %%
print(filePath)
# Out:
# /content/drive/My Drive/cnn-dailymail/cnn_stories_tokenized

# %%
# !ls
# Out:
# adc.json  drive  sample_data

# %%
# !pip install -U -q PyDrive

# %%
#import os
#from pydrive.auth import GoogleAuth
#from pydrive.drive import GoogleDrive
#from google.colab import auth
#from oauth2client.client import GoogleCredentials

#auth.authenticate_user()
#gauth = GoogleAuth()
#gauth.credentials = GoogleCredentials.get_application_default()
#drive = GoogleDrive(gauth)

# %%
#!unzip -q "/content/drive/My Drive/AIML-MRC-Capstone/code/cnn-dailymail/cnn_stories_tokenized.zip"

# %%
#!unzip "/content/drive/My Drive/AIML-MRC-Capstone/code/cnn-dailymail/cnn_stories_tokenized.zip" -d "/content/drive/My Drive/AIML-MRC-Capstone/code/cnn-dailymail/tknz/"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/My Drive/AIML-MRC-Capstone/code/cnn-dailymail/tknz/cnn_stories_tokenized/0b6d5cf34240aea1a6c8c6ff09ff5c91d0de6cfb.story
#   inflating: /content/drive/My Drive/AIML-MRC-Capstone/code/cnn-dailymail/tknz/cnn_stories_tokenized/25057b5d8a969ab5953ddb513a77957eedbd5f3b.story
#   inflating: /content/drive/My Drive/AIML-MRC-Capstone/code/cnn-dailymail/tknz/cnn_stories_tokenized/f3fe5678c39a2cebdc0aa7a6e87464db00e587a3.story
#   inflating: /content/drive/My Drive/AIML-MRC-Capstone/code/cnn-dailymail/tknz/cnn_stories_tokenized/de1ededac564c33c0d10c760efdd8fdcd2443fc1.story
#   inflating: /content/drive/My Drive/AIML-MRC-Capstone/code/cnn-dailymail/tknz/cnn_stories_tokenized/94f0b6de406c956b665cc6630d62132f0d83aca8.story
#   inflating: /content/drive/My Drive/AIML-MRC-Capstone/code/cnn-dailymail/tknz/cnn_stories_tokenized/4801319076f6b32c34e71875175843ec71198d4a.story
# ...

# %%
import os

list = os.listdir('/content/drive/My Drive/cnn-dailymail/cnn_stories_tokenized') # dir is your directory path
number_files = len(list)
print(number_files)
# Out:
# 87989

# %%
list
# Out:
# ['cnnData.ipynb', 'cnn_stories_tokenized', 'cnn_stories_tokenized.zip', 'tknz']

# %%
def load_doc(filename):
	# open the file as read only
	file = open(filename, encoding='utf-8')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

# load all stories in a directory
def load_stories(directory):
	stories = []
	for name in listdir(directory):
		filename = directory + '/' + name
		# load document
		doc = load_doc(filename)
		# split into story and highlights
		story, highlights = split_story(doc)
		# store
		stories.append({'story':story, 'highlights':highlights})
	return stories


# split a document into news story and highlights  
def split_story(doc):
	# find first highlight
	index = doc.find('@highlight')
	# split into story and highlights
	story, highlights = doc[:index], doc[index:].split('@highlight')
	# strip extra white space around each highlight
	highlights = [h.strip() for h in highlights if len(h) > 0]
	return story, highlights

# %%
from os import listdir
 
 
# load stories
directory = '/content/drive/My Drive/cnn-dailymail/cnn_stories_tokenized/'
stories = load_stories(directory)

#print('Loaded Stories %d' % len(stories))

# %%
print('Loaded Stories %d' % len(stories))
# Out:
# Loaded Stories 92579

# %%
print(stories[4]['story'])
# Out:
# -LRB- CNN -RRB- -- Canadian investigators want to talk to actress Pamela Anderson about her recent revelation that she suffered sexual abuse as a child .
#
# Anderson , 46 , described several incidents of sex abuse at the launch of her charity , the Pamela Anderson Foundation , at the Cannes Film Festival in France on Friday . The incidents started at age 6 , she said , when she was molested by a babysitter .
#
# The former `` Baywatch '' star grew up in British Columbia before starting her modeling and acting career in the United States .
#
# `` Given the nature of the allegations , an investigator with the Ladysmith RCMP is in the process of reaching out to Ms. Anderson to discuss this matter with her directly , '' Royal Canadian Mounted Police spokesman Darren Lagan said Thursday . `` Given the sensitive nature of these allegations , and out of respect for Ms. Anderson 's privacy , we will provide no further comment at this time . ''
#
# ...

# %%
print(stories[4]['highlights'])
# Out:
# ["RCMP is `` reaching out to Ms. Anderson to discuss this matter , '' police spokesman says", 'Anderson described childhood sex abuse at an event in France', "`` Baywatch '' actress says she never told her parents about molestation , rapes", "`` I feel now might be the time to reveal some of my most painful memories , '' she says"]

# %%
stories_df = pd.DataFrame(stories,columns=['Story','Highlights'])

# %%
stories_df.head(5)
